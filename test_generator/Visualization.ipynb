# %%
import matplotlib.pyplot as plt

# %%
iter1 = [   [[150, 0.0341], [200, 0.0341], [250, 0.0341], [300, 0.0341], [100, 0.0314], [50, 0.0282]]   ,
            [[150, 0.0176], [200, 0.0176], [300, 0.017], [100, 0.0144], [250, 0.0144], [50, 0.0027]] ,
            [[300, 0.0296], [250, 0.0276], [200, 0.0261], [150, 0.0239], [100, 0.0215], [50, 0.0189]]   ,
            [[100, 0.0341], [200, 0.0341], [250, 0.0341], [300, 0.0341], [50, 0.0314], [150, 0.0314]]   ,
            [[100, 0.0341], [150, 0.0341], [200, 0.0341], [250, 0.0341], [300, 0.0341], [50, 0.0333]]    ]
for i in range(len(iter1)):
    iter1[i].sort()
    iter1[i] = list(map(list, zip(*iter1[i]))) #transpose list of lists

top = [ [[7, 0.0341], [11, 0.0341], [13, 0.0314], [5, 0.0288], [2, 0.0282], [3, 0.0256], [1, 0.0229]] ,
        [[11, 0.0314], [7, 0.0235], [13, 0.0235], [3, 0.0229], [5, 0.0229], [2, 0.0203], [1, 0.0165]] ,
        [[5, 0.0341], [7, 0.0341], [11, 0.0341], [13, 0.0341], [2, 0.0333], [3, 0.0333], [1, 0.0291]] ,
        [[13, 0.0288], [7, 0.0261], [11, 0.0261], [5, 0.0256], [2, 0.0203], [3, 0.0176], [1, 0.0053]] ,
        [[11, 0.0341], [13, 0.0341], [3, 0.0326], [5, 0.0326], [7, 0.0326], [2, 0.0279], [1, 0.0196]] ]
for i in range(len(top)):
    top[i].sort()
    top[i] = list(map(list, zip(*top[i]))) #transpose list of lists

drate = [  [[7, 0.0229], [11, 0.0229], [19, 0.0197], [5, 0.0176], [13, 0.0176], [17, 0.0176], [3, 0.0138], [23, 0.0085], [31, 0.0053], [29, 0.0027]] ,
            [[7, 0.0341], [11, 0.0341], [13, 0.0341], [17, 0.0341], [5, 0.0333], [3, 0.0318], [19, 0.0318], [23, 0.0303], [29, 0.0254], [31, 0.0222]] , 
            [[7, 0.0229], [13, 0.0224], [11, 0.0202], [5, 0.0198], [17, 0.019], [19, 0.0158], [23, 0.0134], [3, 0.0097], [29, 0.0074], [31, 0.0052]] ,
            [[5, 0.0341], [7, 0.0341], [11, 0.0341], [13, 0.0341], [17, 0.0341], [3, 0.0314], [23, 0.0314], [19, 0.0288], [29, 0.0235], [31, 0.0229]] ,
            [[13, 0.0254], [11, 0.0231], [7, 0.021], [17, 0.0195], [5, 0.0183], [19, 0.0174], [3, 0.0117], [23, 0.0114], [29, 0.0064], [31, 0.005]] ]
for i in range(len(drate)):
    drate[i].sort()
    drate[i] = list(map(list, zip(*drate[i]))) #transpose list of lists

retry = [   [[2, 0.0341], [3, 0.0341], [5, 0.0341], [7, 0.0333], [13, 0.0333], [11, 0.0331], [9, 0.0329]] ,
            [[7, 0.0311], [3, 0.0306], [11, 0.0293], [2, 0.0288], [13, 0.0288], [5, 0.0277], [9, 0.0276]] ,
            [[13, 0.0125], [7, 0.0116], [9, 0.0115], [3, 0.0114], [2, 0.0112], [11, 0.0111], [5, 0.0102]] ,
            [[7, 0.0333], [13, 0.0333], [11, 0.0331], [5, 0.032], [9, 0.0317], [2, 0.0314], [3, 0.0284]] ,
            [[7, 0.0148], [9, 0.0128], [13, 0.0118], [5, 0.0115], [3, 0.0114], [11, 0.0108], [2, 0.0085]] ]
for i in range(len(retry)):
    retry[i].sort()
    retry[i] = list(map(list, zip(*retry[i]))) #transpose list of lists

fig, (axs1, axs2, axs3, axs4) = plt.subplots(1, 4,sharey=True, figsize = (24,4))
for i in iter1:
    axs1.plot(i[0], i[1])
axs1.set(xlabel = 'No. iteration', ylabel = 'Reduction mean')

for i in top:
    axs2.plot(i[0], i[1])
axs2.set(xlabel = 'Search space')

for i in drate:
    axs3.plot(i[0], i[1])
axs3.set(xlabel = 'Drop rate')

for i in retry:
    axs4.plot(i[0], i[1])
axs4.set(xlabel = 'No. retry')
# Out:
# [Text(0.5, 0, 'No. retry')]

# %%
iter1 = [   [[300, 0.2112], [250, 0.208], [150, 0.2068], [200, 0.2046], [100, 0.1934], [50, 0.1884]]   ,
            [[300, 0.2066], [150, 0.2044], [200, 0.2037], [250, 0.2014], [100, 0.1892], [50, 0.1793]] ,
            [[250, 0.1523], [200, 0.15], [300, 0.1499], [150, 0.1466], [100, 0.1413], [50, 0.1396]]   ,
            [[250, 0.2139], [300, 0.2129], [200, 0.2099], [150, 0.2094], [100, 0.2003], [50, 0.1835]]   ,
            [[250, 0.1537], [300, 0.1529], [200, 0.1511], [150, 0.1475], [100, 0.1453], [50, 0.1384]]    ]
for i in range(len(iter1)):
    iter1[i].sort()
    iter1[i] = list(map(list, zip(*iter1[i]))) #transpose list of lists

top = [ [[11, 0.2024], [13, 0.1997], [7, 0.1886], [5, 0.184], [3, 0.1761], [2, 0.1756], [1, 0.1527]] ,
        [[7, 0.1654], [13, 0.1648], [11, 0.1647], [5, 0.1635], [2, 0.1545], [3, 0.154], [1, 0.1479]] ,
        [[13, 0.1881], [11, 0.1862], [7, 0.1834], [5, 0.1782], [3, 0.1739], [2, 0.1708], [1, 0.1634]] ,
        [[13, 0.166], [11, 0.1638], [7, 0.161], [5, 0.1567], [3, 0.1556], [2, 0.1507], [1, 0.1441]] ,
        [[13, 0.2118], [11, 0.203], [7, 0.202], [5, 0.1982], [3, 0.1844], [2, 0.1826], [1, 0.1684]] ]
for i in range(len(top)):
    top[i].sort()
    top[i] = list(map(list, zip(*top[i]))) #transpose list of lists

drate = [  [[7, 0.1609], [11, 0.159], [5, 0.1585], [13, 0.1556], [17, 0.1521], [19, 0.1514], [23, 0.1467], [31, 0.137], [29, 0.1368], [3, 0.1322]] ,
            [[5, 0.1958], [7, 0.1917], [3, 0.1831], [11, 0.1814], [13, 0.1766], [19, 0.1697], [17, 0.1669], [23, 0.1594], [29, 0.1589], [31, 0.1553]] , 
            [[13, 0.1686], [5, 0.1661], [7, 0.1653], [11, 0.1629], [3, 0.1586], [19, 0.1544], [17, 0.1524], [23, 0.1515], [29, 0.1442], [31, 0.1432]] ,
            [[5, 0.1999], [7, 0.199], [3, 0.1935], [11, 0.1881], [13, 0.1807], [17, 0.1748], [19, 0.1724], [23, 0.1672], [29, 0.1594], [31, 0.1579]] ,
            [[7, 0.1682], [5, 0.1675], [11, 0.1663], [13, 0.1627], [3, 0.1596], [19, 0.1574], [17, 0.1552], [23, 0.1521], [29, 0.1479], [31, 0.1426]] ]
for i in range(len(drate)):
    drate[i].sort()
    drate[i] = list(map(list, zip(*drate[i]))) #transpose list of lists

retry = [   [[11, 0.2105], [13, 0.2096], [2, 0.2095], [5, 0.2087], [3, 0.2081], [7, 0.2076], [9, 0.2076]] ,
            [[7, 0.2086], [11, 0.2084], [13, 0.2083], [9, 0.2073], [5, 0.2048], [3, 0.2034], [2, 0.202]] ,
            [[7, 0.1625], [11, 0.1625], [9, 0.1623], [5, 0.1619], [2, 0.1618], [3, 0.1618], [13, 0.1617]] ,
            [[11, 0.1479], [5, 0.1466], [9, 0.1444], [7, 0.1442], [3, 0.1437], [13, 0.1437], [2, 0.1407]] ,
            [[3, 0.2111], [9, 0.2107], [5, 0.2103], [2, 0.2102], [11, 0.2099], [13, 0.2092], [7, 0.2091]] ]
for i in range(len(retry)):
    retry[i].sort()
    retry[i] = list(map(list, zip(*retry[i]))) #transpose list of lists

fig, (axs1, axs2, axs3, axs4) = plt.subplots(1, 4,sharey=True, figsize = (24,4))
for i in iter1:
    axs1.plot(i[0], i[1])
axs1.set(xlabel = 'No. iteration', ylabel = 'Reduction mean')

for i in top:
    axs2.plot(i[0], i[1])
axs2.set(xlabel = 'Search space')

for i in drate:
    axs3.plot(i[0], i[1])
axs3.set(xlabel = 'Drop rate')

for i in retry:
    axs4.plot(i[0], i[1])
axs4.set(xlabel = 'No. retry')
# Out:
# [Text(0.5, 0, 'No. retry')]

# %%
iter1 = [   [[250, 0.0261], [300, 0.0252], [200, 0.0242], [150, 0.0225], [100, 0.0209], [50, 0.0208]]   ,
            [[200, 0.006], [250, 0.0056], [300, 0.0047], [150, 0.0032], [100, 0.0031], [50, 0.0029]] ,
            [[150, 0.0052], [300, 0.0051], [250, 0.0043], [100, 0.0032], [200, 0.0032], [50, 0.0009]]   ,
            [[250, 0.0252], [200, 0.0237], [300, 0.0217], [150, 0.0214], [100, 0.0205], [50, 0.0172]]   ,
            [[150, 0.0177], [300, 0.0156], [250, 0.0144], [200, 0.0142], [100, 0.0132], [50, 0.0105]]    ]
for i in range(len(iter1)):
    iter1[i].sort()
    iter1[i] = list(map(list, zip(*iter1[i]))) #transpose list of lists

top = [ [[13, 0.0237], [11, 0.0203], [7, 0.0199], [5, 0.0198], [3, 0.0149], [1, 0.0136], [2, 0.0077]] ,
        [[7, 0.0269], [11, 0.0262], [13, 0.0245], [5, 0.0241], [3, 0.0199], [2, 0.0176], [1, 0.0143]] ,
        [[11, 0.0128], [7, 0.0118], [5, 0.0117], [13, 0.0111], [3, 0.0059], [2, 0.0047], [1, 0.0036]] ,
        [[7, 0.0236], [13, 0.0228], [11, 0.0223], [5, 0.0207], [3, 0.0186], [2, 0.0151], [1, 0.0111]] ,
        [[13, 0.0137], [11, 0.0122], [7, 0.0105], [5, 0.0103], [3, 0.0071], [2, 0.0045], [1, 0.0013]] ]
for i in range(len(top)):
    top[i].sort()
    top[i] = list(map(list, zip(*top[i]))) #transpose list of lists

drate = [  [[5, 0.0121], [13, 0.0108], [7, 0.0072], [17, 0.0068], [19, 0.0057], [11, 0.0042], [23, 0.002], [3, 0.0018], [29, 0.0007], [31, 0.0007]] ,
            [[7, 0.0132], [5, 0.0128], [11, 0.0118], [13, 0.0112], [17, 0.0104], [3, 0.0048], [19, 0.0044], [29, 0.0032], [23, 0.0029], [31, 0.0]] , 
            [[5, 0.0251], [11, 0.0248], [13, 0.0223], [7, 0.0222], [3, 0.0221], [17, 0.0197], [19, 0.0179], [23, 0.0161], [29, 0.0092], [31, 0.0077]] ,
            [[7, 0.0103], [13, 0.0087], [11, 0.0074], [3, 0.0068], [17, 0.0066], [23, 0.0061], [5, 0.0039], [19, 0.0024], [29, 0.0], [31, 0.0]] ,
            [[11, 0.0249], [7, 0.0245], [5, 0.0241], [13, 0.0229], [3, 0.0221], [17, 0.019], [19, 0.0182], [23, 0.0165], [29, 0.0095], [31, 0.0086]] ]
for i in range(len(drate)):
    drate[i].sort()
    drate[i] = list(map(list, zip(*drate[i]))) #transpose list of lists

retry = [   [[3, 0.0272], [5, 0.0271], [13, 0.0265], [11, 0.0262], [7, 0.026], [9, 0.0257], [2, 0.0255]] ,
            [[3, 0.0034], [7, 0.0029], [13, 0.0027], [2, 0.0024], [11, 0.0023], [5, 0.0022], [9, 0.0012]] ,
            [[5, 0.0065], [9, 0.0026], [11, 0.0023], [2, 0.002], [7, 0.0019], [13, 0.0019], [3, 0.0006]] ,
            [[3, 0.0127], [2, 0.0116], [13, 0.0088], [5, 0.0085], [9, 0.0078], [7, 0.0075], [11, 0.0064]] ,
            [[9, 0.0144], [13, 0.0141], [11, 0.0139], [7, 0.0138], [3, 0.0131], [5, 0.0126], [2, 0.0123]] ]
for i in range(len(retry)):
    retry[i].sort()
    retry[i] = list(map(list, zip(*retry[i]))) #transpose list of lists

fig, (axs1, axs2, axs3, axs4) = plt.subplots(1, 4,sharey=True, figsize = (24,4))
for i in iter1:
    axs1.plot(i[0], i[1])
axs1.set(xlabel = 'No. iteration', ylabel = 'Reduction mean')

for i in top:
    axs2.plot(i[0], i[1])
axs2.set(xlabel = 'Search space')

for i in drate:
    axs3.plot(i[0], i[1])
axs3.set(xlabel = 'Drop rate')

for i in retry:
    axs4.plot(i[0], i[1])
axs4.set(xlabel = 'No. retry')
# Out:
# [Text(0.5, 0, 'No. retry')]
